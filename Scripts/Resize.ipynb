# %%
import cv2
import os
#Official
# Function to resize images
def resize_images(input_folder, output_folder, width, height):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            img_path = os.path.join(input_folder, filename)
            img = cv2.imread(img_path)
            if img is None:
                continue
            resized_img = cv2.resize(img, (width, height))
            output_path = os.path.join(output_folder, filename)
            cv2.imwrite(output_path, resized_img)
            print(f'Resized and saved {filename}')

# Input and output folder paths
input_folder = r"C:\Users\hp\OneDrive - Efrei\TahaDataCorrectlyAnnotated\Canter\icelandic horse - galop 1"
output_folder = r"C:\Users\hp\OneDrive - Efrei\TahaDataCorrectlyAnnotated\Canter\Resize\icelandic horse - galop 1" # Replace with your output folder path

# Desired resolution
new_width = 1280
new_height = 720

# Call the function to resize the images
resize_images(input_folder, output_folder, new_width, new_height)
# Out:
# Resized and saved 00000.jpg
# Resized and saved 00001.jpg
# Resized and saved 00002.jpg
# Resized and saved 00003.jpg
# Resized and saved 00004.jpg
# Resized and saved 00005.jpg
# Resized and saved 00006.jpg
# Resized and saved 00007.jpg
# Resized and saved 00008.jpg
# Resized and saved 00009.jpg
# Resized and saved 00010.jpg
# Resized and saved 00011.jpg
# Resized and saved 00012.jpg
# Resized and saved 00013.jpg
# Resized and saved 00014.jpg
# Resized and saved 00015.jpg
# Resized and saved 00016.jpg
# Resized and saved 00017.jpg
# Resized and saved 00018.jpg
# Resized and saved 00019.jpg
# Resized and saved 00020.jpg
# Resized and saved 00021.jpg
# Resized and saved 00022.jpg
# Resized and saved 00023.jpg
# Resized and saved 00024.jpg
# Resized and saved 00025.jpg
# Resized and saved 00026.jpg
# Resized and saved 00027.jpg
# Resized and saved 00028.jpg
# Resized and saved 00029.jpg
# Resized and saved 00030.jpg
# Resized and saved 00031.jpg
# Resized and saved 00032.jpg
# ...

# %%
#one frame resize

import cv2
import os

#change the input path
img_path=r"C:\Users\hp\Downloads\StandingHorse.jpg"
img = cv2.imread(img_path)
resized_img = cv2.resize(img, (1280, 720))
#change the output path
cv2.imwrite(r"C:\Users\hp\Downloads\StandingHorseResized.jpg", resized_img)
# Out:
# True
